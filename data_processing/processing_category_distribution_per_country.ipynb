# %%
import csv
import json
from functools import reduce
import dateutil.parser

# %%
def get_rows(filename):
    rows = []
    video_ids = {}
    with open(filename, "r", encoding="ISO-8859-1") as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')  # encoding = "ISO-8859-1"
        line_count = 0
        for row in csv_reader:
            if line_count == 0:
                cols = ", ".join(row)
                c = list(map(lambda e: (e, row[e]), range(len(row))))
                #print(c)
            else:
                if row[0] not in video_ids:
                    video_ids[row[0]] = 1
                    rows.append([row[1], int(row[4]), dateutil.parser.isoparse(row[5]), int(row[7]), int(row[8]), int(row[9]), int(row[10])])
            line_count += 1
    return rows

# %%
def group_by_category(rows):
    categories = {}
    for row in rows:
        cat_id = str(row[1])
        if cat_id not in categories:
            categories[cat_id] = {
                "count": 0,
                "views": 0
            }
        categories[cat_id]["count"] += 1
        categories[cat_id]["views"] += row[3]
    return categories

# %% [markdown]
# For the firs graph of our visualization (map with category distribution per category) we need the following data for each country:
# 1. Number of total views
# 2. Number of videos
# 3. Average number of views per video (Number of total views / Number of videos)
# 4. The distribution of views and number of videos per category

# %%
def category_distribution_per_nation():
    distr = {}
    nations = ["CA", "DE", "FR", "GB", "IN", "JP", "KR", "MX", "RU", "US"]
    for nation in nations:
        print(f"Preparing for nation: {nation}")
        filename = f"../youtube-new/{nation}videos.csv"
        rows = get_rows(filename)
        distribution = group_by_category(rows)
                
        nb_views = reduce(lambda acc, val: acc + val["views"], list(distribution.values()), 0)
        nb_videos = reduce(lambda acc, val: acc + val["count"], list(distribution.values()), 0)
        
        distr[nation] = {
            "category_distribution": distribution,
            "nb_views": nb_views,
            "nb_videos": nb_videos,
            "avg_views_per_video": int(nb_views / nb_videos)
        }
    return distr

distribution = category_distribution_per_nation()
# Out:
# Preparing for nation: CA
# Preparing for nation: DE
# Preparing for nation: FR
# Preparing for nation: GB
# Preparing for nation: IN
# Preparing for nation: JP
# Preparing for nation: KR
# Preparing for nation: MX
# Preparing for nation: RU
# Preparing for nation: US

# %%
distribution
# Out:
# {'CA': {'category_distribution': {'10': {'count': 1564, 'views': 2055194663},
#    '23': {'count': 1946, 'views': 1080548028},
#    '24': {'count': 8248, 'views': 3724671352},
#    '25': {'count': 2941, 'views': 645131321},
#    '22': {'count': 2559, 'views': 929579787},
#    '26': {'count': 1272, 'views': 541943057},
#    '1': {'count': 1151, 'views': 609046665},
#    '28': {'count': 636, 'views': 362522426},
#    '20': {'count': 772, 'views': 386218794},
#    '17': {'count': 1932, 'views': 1069969973},
#    '29': {'count': 50, 'views': 24957964},
#    '15': {'count': 211, 'views': 80578126},
#    '19': {'count': 202, 'views': 49516868},
#    '2': {'count': 248, 'views': 83092413},
#    '27': {'count': 590, 'views': 174064063},
#    '43': {'count': 104, 'views': 55528692},
#    '30': {'count': 1, 'views': 225528}},
#   'nb_views': 11872789720,
#   'nb_videos': 24427,
#   'avg_views_per_video': 486051},
#  'DE': {'category_distribution': {'24': {'count': 10846, 'views': 3222709357},
#    '23': {'count': 1756, 'views': 851800542},
#    '27': {'count': 662, 'views': 74415644},
#    '22': {'count': 4476, 'views': 953735642},
#    '1': {'count': 1642, 'views': 577568114},
#    '2': {'count': 674, 'views': 110358447},
#    '17': {'count': 2090, 'views': 895294617},
#    '26': {'count': 1381, 'views': 303509500},
#    '25': {'count': 2370, 'views': 488143926},
#    '10': {'count': 1373, 'views': 1401771571},
#    '20': {'count': 1090, 'views': 289788005},
#    '43': {'count': 99, 'views': 44631704},
#    '28': {'count': 647, 'views': 213797837},
#    '29': {'count': 202, 'views': 70768725},
#    '15': {'count': 202, 'views': 47174225},
#    '19': {'count': 115, 'views': 15208015},
#    '44': {'count': 1, 'views': 8804},
#    '30': {'count': 1, 'views': 781977}},
#   'nb_views': 9561466652,
#   'nb_videos': 29627,
#   'avg_views_per_video': 322728},
#  'FR': {'category_distribution': {'24': {'count': 7595, 'views': 1995334349},
#    '23': {'count': 2597, 'views': 692869299},
#    '20': {'count': 1094, 'views': 205708473},
#    '17': {'count': 3436, 'views': 1043144816},
#    '22': {'count': 4644, 'views': 659645455},
#    '27': {'count': 564, 'views': 55810981},
#    '26': {'count': 1892, 'views': 260649267},
#    '28': {'count': 534, 'views': 133823484},
#    '2': {'count': 591, 'views': 31031948},
#    '25': {'count': 3084, 'views': 304151337},
#    '1': {'count': 1657, 'views': 380469177},
#    '10': {'count': 2391, 'views': 1432880510},
#    '43': {'count': 95, 'views': 48484072},
#    '19': {'count': 97, 'views': 4143660},
#    '15': {'count': 195, 'views': 28974512},
#    '29': {'count': 104, 'views': 23144279},
#    '30': {'count': 10, 'views': 993454},
#    '44': {'count': 1, 'views': 3136}},
#   'nb_views': 7301262209,
#   'nb_videos': 30581,
#   'avg_views_per_video': 238751},
#  'GB': {'category_distribution': {'26': {'count': 188, 'views': 53169625},
#    '24': {'count': 859, 'views': 931136760},
#    '10': {'count': 875, 'views': 2340066368},
#    '17': {'count': 213, 'views': 116728796},
#    '25': {'count': 127, 'views': 54162901},
#    '22': {'count': 286, 'views': 159612182},
#    '23': {'count': 204, 'views': 199914569},
#    '28': {'count': 42, 'views': 46400839},
#    '15': {'count': 41, 'views': 14972620},
#    '27': {'count': 37, 'views': 11904956},
#    '1': {'count': 197, 'views': 189889886},
#    '20': {'count': 173, 'views': 87607019},
#    '2': {'count': 14, 'views': 8987658},
#    '19': {'count': 10, 'views': 4434990},
#    '29': {'count': 6, 'views': 8448357}},
#   'nb_views': 4227437526,
#   'nb_videos': 3272,
#   'avg_views_per_video': 1292004},
#  'IN': {'category_distribution': {'1': {'count': 520, 'views': 444668612},
#    '25': {'count': 2506, 'views': 491927066},
#    '24': {'count': 7558, 'views': 2571923979},
#    '23': {'count': 1116, 'views': 465350340},
#    '10': {'count': 1214, 'views': 1194515647},
#    '22': {'count': 1231, 'views': 378143916},
#    '19': {'count': 4, 'views': 687055},
#    '28': {'count': 301, 'views': 145033513},
#    '27': {'count': 798, 'views': 50939788},
#    '26': {'count': 479, 'views': 303596891},
#    '43': {'count': 109, 'views': 62137475},
#    '17': {'count': 346, 'views': 323577544},
#    '29': {'count': 69, 'views': 3099361},
#    '2': {'count': 33, 'views': 6297064},
#    '15': {'count': 1, 'views': 2244679},
#    '20': {'count': 20, 'views': 41981461},
#    '30': {'count': 2, 'views': 391129}},
#   'nb_views': 6486515520,
#   'nb_videos': 16307,
#   'avg_views_per_video': 397774},
#  'JP': {'category_distribution': {'25': {'count': 919, 'views': 93831888},
#    '1': {'count': 748, 'views': 160297723},
#    '28': {'count': 89, 'views': 72677739},
#    '22': {'count': 2479, 'views': 256578890},
#    '23': {'count': 402, 'views': 130242761},
#    '19': {'count': 78, 'views': 7648997},
#    '15': {'count': 757, 'views': 31617576},
#    '24': {'count': 3830, 'views': 824736099},
#    '26': {'count': 514, 'views': 54563754},
#    '2': {'count': 211, 'views': 10478157},
#    '17': {'count': 1386, 'views': 334038759},
#    '29': {'count': 13, 'views': 1371224},
#    '10': {'count': 809, 'views': 430877654},
#    '20': {'count': 595, 'views': 76977727},
#    '27': {'count': 82, 'views': 6267909}},
#   'nb_views': 2492206857,
#   'nb_videos': 12912,
#   'avg_views_per_video': 193014},
#  'KR': {'category_distribution': {'22': {'count': 3379, 'views': 450851652},
#    '25': {'count': 3728, 'views': 372815367},
#    '17': {'count': 470, 'views': 268097864},
#    '19': {'count': 40, 'views': 7247432},
#    '23': {'count': 829, 'views': 209539162},
#    '10': {'count': 797, 'views': 835590108},
#    '24': {'count': 4073, 'views': 1142757697},
#    '15': {'count': 304, 'views': 38218417},
#    '1': {'count': 870, 'views': 235425060},
#    '43': {'count': 73, 'views': 5587057},
#    '28': {'count': 47, 'views': 89014300},
#    '20': {'count': 598, 'views': 103187778},
#    '29': {'count': 119, 'views': 6426012},
#    '2': {'count': 65, 'views': 4903977},
#    '27': {'count': 232, 'views': 16737891},
#    '26': {'count': 251, 'views': 82154211},
#    '44': {'count': 1, 'views': 13454}},
#   'nb_views': 3868567439,
#   'nb_videos': 15876,
#   'avg_views_per_video': 243673},
#  'MX': {'category_distribution': {'24': {'count': 11183, 'views': 1970888034},
#    '22': {'count': 6963, 'views': 676231382},
#    '25': {'count': 2494, 'views': 242487767},
#    '26': {'count': 2185, 'views': 296179570},
#    '10': {'count': 2572, 'views': 1147486952},
#    '23': {'count': 1290, 'views': 383752874},
#    '17': {'count': 3402, 'views': 873436475},
#    '2': {'count': 220, 'views': 24074135},
#    '1': {'count': 1097, 'views': 242164287},
#    '29': {'count': 211, 'views': 25189664},
#    '27': {'count': 476, 'views': 34905113},
#    '28': {'count': 450, 'views': 82831920},
#    '20': {'count': 802, 'views': 241474986},
#    '15': {'count': 78, 'views': 31571528},
#    '19': {'count': 87, 'views': 9301166},
#    '43': {'count': 3, 'views': 65436}},
#   'nb_views': 6282041289,
#   'nb_videos': 33513,
#   'avg_views_per_video': 187450},
#  'RU': {'category_distribution': {'22': {'count': 8884, 'views': 859966185},
#    '24': {'count': 4772, 'views': 1126702440},
#    '28': {'count': 911, 'views': 217608118},
#    '23': {'count': 2350, 'views': 499207655},
#    '27': {'count': 649, 'views': 28900033},
#    '17': {'count': 1743, 'views': 285980059},
#    '2': {'count': 1349, 'views': 230168094},
#    '25': {'count': 4679, 'views': 444329649},
#    '15': {'count': 562, 'views': 45526538},
#    '20': {'count': 872, 'views': 149137920},
#    '1': {'count': 2573, 'views': 306947290},
#    '43': {'count': 158, 'views': 22534524},
#    '26': {'count': 1839, 'views': 293288637},
#    '10': {'count': 1391, 'views': 656929925},
#    '29': {'count': 1314, 'views': 142167704},
#    '19': {'count': 235, 'views': 14181702},
#    '30': {'count': 1, 'views': 100049}},
#   'nb_views': 5323676522,
#   'nb_videos': 34282,
#   'avg_views_per_video': 155290},
#  'US': {'category_distribution': {'22': {'count': 498, 'views': 354958216},
#    '24': {'count': 1619, 'views': 1322922283},
#    '23': {'count': 547, 'views': 422806173},
#    '28': {'count': 380, 'views': 222042546},
#    '1': {'count': 318, 'views': 292697703},
#    '25': {'count': 505, 'views': 124950593},
#    '17': {'count': 451, 'views': 374456969},
#    '10': {'count': 799, 'views': 1108709326},
#    '15': {'count': 138, 'views': 38654401},
#    '27': {'count': 250, 'views': 87994865},
#    '26': {'count': 595, 'views': 281517665},
#    '2': {'count': 70, 'views': 28445164},
#    '19': {'count': 60, 'views': 14490662},
#    '20': {'count': 103, 'views': 124819911},
#    '29': {'count': 14, 'views': 14353032},
#    '43': {'count': 4, 'views': 1569435}},
#   'nb_views': 4815388944,
#   'nb_videos': 6351,
#   'avg_views_per_video': 758209}}
